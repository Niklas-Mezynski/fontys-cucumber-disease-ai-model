# %% [markdown]
# # Procedure for image preprocessing
#
# ## Setup

# %%
# %load_ext nb_black
# %matplotlib notebook
import scipy
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import cv2
from PIL import ImageStat
import random
import os
from dotenv import load_dotenv

# %%
load_dotenv()
os.environ.get("TRAINING_DIRECTORY_SECOND")
# Out:
# 'F:/big-data/uni/minor-a-systems/cucumber-second-dataset/normal-view'

# %% [markdown]
# ## Define constants and read the data

# %%
# Set the path to the folders containing the images
# train_dir = './training_data/'
train_dir = os.environ.get("TRAINING_DIRECTORY_SECOND")

# Define the image size
img_height = 3288
img_width = 4608

# %%
# Read in the images and resize them
classes = ["healthy", "infected"]
images = []
labels = []
img_paths = []
img_dir = f"{train_dir}/healthy"
for img_file in os.listdir(img_dir):
    path = os.path.join(img_dir, img_file)
    img = tf.keras.preprocessing.image.load_img(
        path, target_size=(img_height, img_width)
    )
    img = tf.keras.preprocessing.image.img_to_array(img, dtype=np.uint8)
    images.append(img)
    labels.append(0)
    img_paths.append(path)

img_dir = f"{train_dir}/infected"
for img_file in os.listdir(img_dir):
    path = os.path.join(img_dir, img_file)
    img = tf.keras.preprocessing.image.load_img(
        path, target_size=(img_height, img_width)
    )
    img = tf.keras.preprocessing.image.img_to_array(img, dtype=np.uint8)
    images.append(img)
    labels.append(1)
    img_paths.append(path)

# Convert the data and labels to NumPy arrays
images = np.array(images)
labels = np.array(labels)
img_paths = np.array(img_paths)

# %%
images.shape
# Out:
# (71, 3288, 4608, 3)

# %% [markdown]
# ## Store some information about the dataset into a Dataframe
#
# - The cucumber image is masked (where the BLUE channel is below some threshold to filter out the background)
# - The first row is found where the mask contains at least 1/64 true values (sorting out possible single pixels that were not filtered out)
#     - This is considered the start y-pixel-coordinate of the cucumber
# - From there search the first row where there are less than 1/64 true values
#     - This is considered the end y-pixel-coordinate of the cucumber
# - Same process is repeated for columns to get the x-pixel-coordinates

# %%
# Crop images to the conveyor belt size
start_x, start_y, end_x, end_y = 0, 1130, img_width, 2000

new_images = []

for (index, image) in enumerate(images):

    # Crop images to both sides
    image = image[
        start_y: end_y,
        start_x: end_x,
    ]
    new_images.append(image)

images = np.array(new_images)
images.shape
# Out:
# (71, 870, 4608, 3)

# %%
# # Map all images to their blue channel and flatten them
# images_blue_flattened = []
# for image in images:
#     images_blue_flattened.append(images[0][:, :, 2].ravel())
# images_blue_flattened = np.array(images_blue_flattened)
# print(f'Shape: {images_blue_flattened.shape}')

# # -- Plot the average number of blue pixels per image --
# mean = np.median(images_blue_flattened, axis=0)
# plt.hist(mean, bins=int(255/5))

# # -- Use the histogram to find the threshold for masking the background --

# %%
def get_first_and_last_cucumber_pixel(image):
    # masked_img = image[..., 2] < MASK_BLUE_THRESHOLD

    (_, masked_img) = cv2.threshold(
        image[..., 2], 5, 1, cv2.THRESH_BINARY)

    first_cucumber_pixel_y = None
    last_cucumber_pixel_y = None
    threshold_height = img_height / 64
    for i in range(masked_img.shape[0]):
        if np.sum(masked_img[i, :]) > threshold_height:
            first_cucumber_pixel_y = i
            j = first_cucumber_pixel_y
            for j in range(i, masked_img.shape[0]):
                last_cucumber_pixel_y = j
                if np.sum(masked_img[j, :]) <= threshold_height:
                    break
            break

    first_cucumber_pixel_x = None
    last_cucumber_pixel_x = None
    threshold_width = 2
    threshold_min_width = img_width / 16
    for i in range(masked_img.shape[1]):
        if np.sum(masked_img[:, i]) > threshold_width:
            first_cucumber_pixel_x = i
            for j in range(first_cucumber_pixel_x, masked_img.shape[1]):
                last_cucumber_pixel_x = j
                if np.sum(masked_img[:, j]) <= threshold_width and j - first_cucumber_pixel_x > threshold_min_width:
                    break
            break

    return (
        (first_cucumber_pixel_x, first_cucumber_pixel_y),
        (last_cucumber_pixel_x, last_cucumber_pixel_y),
    )

# %%
def mask_cucumber(img):
    # Convert the image to the HSV color space
    hsv_img = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)

    # Define the lower and upper bounds for the green color in HSV
    # Adjust these values to fit your specific shade of green
    lower_green = np.array([40, 40, 40])
    # Adjust these values to fit your specific shade of green
    upper_green = np.array([70, 255, 255])
    # lower_green = np.array([.1/255 * 23, .1/255 * 20,.1/255 * 14])
    # upper_green = np.array([.1/255 * 142, 255, 255])

    # Create a mask for the green pixels within the specified range
    mask = cv2.inRange(hsv_img, lower_green, upper_green)

    # Apply image morphology operations to enhance the blobs
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    opening = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)
    sure_bg = cv2.dilate(opening, kernel, iterations=3)

    # Perform blob detection on the masked image
    contours, _ = cv2.findContours(
        sure_bg, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Get the bounding coordinates rectangle for the largest blob
    first_x, first_y, last_x, last_y = 99999, 99999, 0, 0
    for contour in contours:
        (x, y, w, h) = cv2.boundingRect(contour)
        first_x = min(first_x, x)
        first_y = min(first_y, y)
        last_x = max(last_x, x + w)
        last_y = max(last_y, y + h)

    # Create a blank mask image
    mask_image = np.zeros_like(img)

    # Draw filled contours on the mask image
    cv2.drawContours(mask_image, contours, -1,
                     (255, 255, 255), thickness=cv2.FILLED)

    # Apply the mask to the original image
    masked_img = cv2.bitwise_and(img, mask_image)

    return (masked_img, (first_x, first_y, last_x, last_y))


plt.figure(figsize=(10, 10))
for i in range(9):
    rand_idx = random.randint(0, images.shape[0] - 1)
    ax = plt.subplot(3, 3, i + 1)
    masked_image, (first_x, first_y, last_x, last_y) = mask_cucumber(image)

    rect = patches.Rectangle(
        (
            first_x, first_y
        ),
        last_x - first_x,
        last_y - first_y,
        linewidth=1,
        edgecolor="r",
        facecolor="none",
    )

    ax.add_patch(rect)

    plt.imshow(masked_image)
    path = img_paths[rand_idx].split(os.sep)[-1]
    plt.title(f"{classes[labels[rand_idx]]} ({path})")
    plt.axis("off")

# %%
# Apply the mask cucumber function to each image in the numpy images array
masked_images = []
df_records = []

for image in images:
    masked_image, (first_x, first_y, last_x, last_y) = mask_cucumber(image)
    masked_images.append(masked_image)
    df_records.append({
        "idx": i,
        "label": classes[labels[i]],
        'first_x': first_x,
        'first_y': first_y,
        'last_x': last_x,
        'last_y': last_y,
        "cucumber_height": last_y - first_y,
        "cucumber_width": last_x - first_x,
    })

# Convert the masked images to a numpy array
images = np.array(masked_images)
df = pd.DataFrame(df_records)

print(df)
# Out:
#     idx    label  first_x  first_y  last_x  last_y  cucumber_height  \
# 0     8  healthy      145       76    4512     777              701
# 1     8  healthy       43        0    4125     739              739
# 2     8  healthy      406       81    4096     709              628
# 3     8  healthy      100        0    4235     806              806
# 4     8  healthy      559       45    4355     723              678
# ..  ...      ...      ...      ...     ...     ...              ...
# 66    8  healthy      244       13    4419     796              783
# 67    8  healthy      239       63    4346     795              732
# 68    8  healthy      745       42    4332     777              735
# 69    8  healthy      728        0    4384     740              740
# 70    8  healthy      622       44    4426     668              624
#
#     cucumber_width
# 0             4367
# 1             4082
# 2             3690
# 3             4135
# 4             3796
# ..             ...
# 66            4175
# 67            4107
# 68            3587
# 69            3656
# 70            3804
#
# [71 rows x 8 columns]

# %%
# Crop the image to the cucumber tip
image_size = int(img_width / 4)
img_size_final = 224
def crop_cucumber_tip(img, first_x, first_y, last_x, last_y):
    # Append black pixels in the y direction of the image
    image_size = last_x - first_x
    img = np.concatenate(
        (
            img,
            np.zeros((image_size, img.shape[1], 3)).astype(np.uint8),
        ),
        axis=0,
    )

    # Crop the image
    img = img[first_y: first_y + image_size,
              first_x: first_x + image_size]
    
    img = cv2.resize(src=img, dsize=(img_size_final, img_size_final),
                       interpolation=cv2.INTER_CUBIC)

    return img

# %%
# Use the crop cucumber function to display 9 sample images
plt.figure(figsize=(10, 10))
for i in range(9):
    rand_idx = random.randint(0, images.shape[0] - 1)
    ax = plt.subplot(3, 3, i + 1)

    img = images[rand_idx]
    img = crop_cucumber_tip(img, df.iloc[rand_idx]["first_x"], df.iloc[rand_idx]
                            ["first_y"], df.iloc[rand_idx]["last_x"], df.iloc[rand_idx]["last_y"])

    plt.imshow(img)
    path = img_paths[rand_idx].split(os.sep)[-1]
    plt.title(f"{classes[labels[rand_idx]]} ({path})")
    plt.axis("off")

# %%
final_data = []
for (idx, image) in enumerate(images):
    image = crop_cucumber_tip(image, df.iloc[idx]["first_x"], df.iloc[idx]
                              ["first_y"], df.iloc[idx]["last_x"], df.iloc[idx]["last_y"])
    final_data.append(image)


final_data = np.array(final_data)
final_data.shape
# Out:
# (71, 224, 224, 3)

# %%
i = random.randint(0, images.shape[0] - 1)

print(df.iloc[i])
plt.figure(figsize=(9, 9))
plt.subplot(2, 2, 1)
plt.imshow(final_data[i])
plt.subplot(2, 2, 2)
plt.imshow(images[i])
# Out:
# idx                      8
# label              healthy
# first_x                728
# first_y                  0
# last_x                4384
# last_y                 740
# cucumber_height        740
# cucumber_width        3656
# Name: 69, dtype: object

# %%
plt.figure(figsize=(12,12))

for i in range(25):
    rand_idx = random.randint(0, int((images.shape[0] / 2)) - 10)
    # rand_idx = rand + i
    # rand_idx = 25 + i
    ax = plt.subplot(5, 5, i + 1)

    plt.imshow(final_data[rand_idx])
    path = img_paths[rand_idx].split(os.sep)[-1]
    plt.title(f"{classes[labels[rand_idx]]} ({path})")
    plt.axis("off")
plt.title("Healthy cucumbers")
plt.show()

plt.figure(figsize=(12, 12))

for i in range(25):
    rand_idx = random.randint(int((images.shape[0] / 2))+ 10, (images.shape[0] - 1))
    # rand_idx = rand + i
    # rand_idx = 25 + i
    ax = plt.subplot(5, 5, i + 1)

    plt.imshow(final_data[rand_idx])
    path = img_paths[rand_idx].split(os.sep)[-1]
    plt.title(f"{classes[labels[rand_idx]]} ({path})")
    plt.axis("off")
plt.title("Infected cucumbers")
plt.show()

# %% [markdown]
# ## AI Training
# In the following section the pre_processed images stored in `final_data` are used to train an AI model

# %%
# Find the indices of samples with label 0 and label 1
indices_label_healthy = np.where(labels == 0)[0]
indices_label_unhealthy = np.where(labels == 1)[0]

num_healthy = len(indices_label_healthy)
num_unhealthy = len(indices_label_unhealthy)

healthy_images = final_data[indices_label_healthy]
healthy_labels = labels[indices_label_healthy]
unhealthy_images = final_data[indices_label_unhealthy]
unhealthy_labels = labels[indices_label_unhealthy]

wanted_images_per_class = 100

augmentation_datagen = keras.preprocessing.image.ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# Convert your image array and label array to a generator
image_generator_healthy = augmentation_datagen.flow(
    x=healthy_images,
    y=healthy_labels,
    batch_size=1,
    shuffle=True
)
image_generator_unhealthy = augmentation_datagen.flow(
    x=unhealthy_images,
    y=unhealthy_labels,
    batch_size=1,
    shuffle=True
)

# Create empty arrays to store the augmented images and labels
augmented_images = []
augmented_labels = []

# Generate the augmented images for healthy class and append them to the empty arrays
for i in range(wanted_images_per_class - num_healthy):
    augmented_images.append(image_generator_healthy.next()[0][0])
    augmented_labels.append(0)

# Generate the augmented images for unhealthy class and append them to the empty arrays
for i in range(wanted_images_per_class - num_unhealthy):
    augmented_images.append(image_generator_unhealthy.next()[0][0])
    augmented_labels.append(1)

# Convert the augmented images and labels to numpy arrays
augmented_images = np.array(augmented_images)
augmented_labels = np.array(augmented_labels)

# Concatenate the original images/labels with the augmented images/labels
final_data = np.concatenate((final_data, augmented_images))
labels = np.concatenate((labels, augmented_labels))

# %%
from sklearn.model_selection import train_test_split

counts = np.bincount(labels)

# Create labels for the classes
classes = ['Healthy', 'Infected']

# Plot the bar chart
plt.bar(classes, counts)

# Set the title and labels
plt.title('Class Distribution')
plt.xlabel('Class')
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
# Save the augmented data and labels to disk
# np.save('data', final_data)
# np.save('labels', labels)

# %%
# Split the dataset and normalize the pixel values to be in the range [0, 1]
x_train, x_valid, y_train, y_valid = train_test_split(
    final_data.astype('float32') / 255.0, labels, test_size=0.2, shuffle=True, random_state=187)

print(f'Train: {x_train.shape} | {y_train.shape} Validation: {x_valid.shape} | {y_valid.shape}')
# Out:
# Train: (160, 224, 224, 3) | (160,) Validation: (40, 224, 224, 3) | (40,)

# %%
# Model using VGG16 and data segmentation
input_shape = (x_train.shape[1], x_train.shape[2], x_train.shape[3])

# Load the pre-trained VGG16 model (without the top layer)
vgg16_model = keras.applications.VGG16(weights='imagenet', include_top=False,
                                       input_shape=input_shape)

# Freeze the weights of the pre-trained layers
for index, layer in enumerate(vgg16_model.layers):
    if len(vgg16_model.layers) - index < 4:
        break
    layer.trainable = False

# Create a new model using the pre-trained VGG16 as a base
model = keras.models.Sequential()
model.add(vgg16_model)

# Add new layers for classification on top of the pre-trained base model
# model.add(keras.layers.GlobalAveragePooling2D())
model.add(keras.layers.Flatten())
# model.add(keras.layers.Dense(256, activation='relu'))
# model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy',
              metrics=['accuracy',
                       keras.metrics.Recall(),
                       keras.metrics.Precision(),
                       keras.metrics.AUC()])

# Checkpoints for the model
checkpoint = keras.callbacks.ModelCheckpoint(
    "./models_2/best_model.h5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# Create an ImageDataGenerator for data augmentation
train_datagen = keras.preprocessing.image.ImageDataGenerator(
    # rotation_range=10,
    # width_shift_range=0.1,
    # height_shift_range=0.1,
    # horizontal_flip=True
)

# Train the model using data augmentation
history = model.fit(train_datagen.flow(x_train, y_train, batch_size=32),
                    epochs=60, validation_data=train_datagen.flow(x_train, y_train, batch_size=32))
                    # epochs=60, validation_data=train_datagen.flow(x_train, y_train, batch_size=32), callbacks=[checkpoint])
# Out:
# Epoch 1/60
# 5/5 [==============================] - 6s 459ms/step - loss: 1.0204 - accuracy: 0.5188 - recall_1: 0.4937 - precision_1: 0.5132 - auc_1: 0.5567 - val_loss: 0.6731 - val_accuracy: 0.5063 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_auc_1: 0.8036
# Epoch 2/60
# 5/5 [==============================] - 2s 469ms/step - loss: 0.6486 - accuracy: 0.6375 - recall_1: 0.5190 - precision_1: 0.6721 - auc_1: 0.6775 - val_loss: 0.5332 - val_accuracy: 0.7312 - val_recall_1: 0.7848 - val_precision_1: 0.7045 - val_auc_1: 0.8279
# Epoch 3/60
# 5/5 [==============================] - 2s 556ms/step - loss: 0.5285 - accuracy: 0.7750 - recall_1: 0.7975 - precision_1: 0.7590 - auc_1: 0.8227 - val_loss: 0.4644 - val_accuracy: 0.7875 - val_recall_1: 0.7975 - val_precision_1: 0.7778 - val_auc_1: 0.8637
# Epoch 4/60
# 5/5 [==============================] - 2s 450ms/step - loss: 0.4628 - accuracy: 0.8062 - recall_1: 0.7848 - precision_1: 0.8158 - auc_1: 0.8575 - val_loss: 0.3806 - val_accuracy: 0.8500 - val_recall_1: 0.8228 - val_precision_1: 0.8667 - val_auc_1: 0.9144
# Epoch 5/60
# 5/5 [==============================] - 2s 435ms/step - loss: 0.3831 - accuracy: 0.8562 - recall_1: 0.8101 - precision_1: 0.8889 - auc_1: 0.9046 - val_loss: 0.3092 - val_accuracy: 0.8625 - val_recall_1: 0.8608 - val_precision_1: 0.8608 - val_auc_1: 0.9467
# Epoch 6/60
# 5/5 [==============================] - 2s 507ms/step - loss: 0.3006 - accuracy: 0.9000 - recall_1: 0.8734 - precision_1: 0.9200 - auc_1: 0.9490 - val_loss: 0.2468 - val_accuracy: 0.9312 - val_recall_1: 0.8608 - val_precision_1: 1.0000 - val_auc_1: 0.9778
# Epoch 7/60
# 5/5 [==============================] - 2s 489ms/step - loss: 0.2510 - accuracy: 0.8813 - recall_1: 0.8608 - precision_1: 0.8947 - auc_1: 0.9660 - val_loss: 0.2121 - val_accuracy: 0.9250 - val_recall_1: 0.8481 - val_precision_1: 1.0000 - val_auc_1: 0.9910
# Epoch 8/60
# 5/5 [==============================] - 2s 446ms/step - loss: 0.1759 - accuracy: 0.9375 - recall_1: 0.9114 - precision_1: 0.9600 - auc_1: 0.9837 - val_loss: 0.1389 - val_accuracy: 0.9750 - val_recall_1: 0.9747 - val_precision_1: 0.9747 - val_auc_1: 0.9935
# Epoch 9/60
# 5/5 [==============================] - 2s 492ms/step - loss: 0.1573 - accuracy: 0.9438 - recall_1: 0.8987 - precision_1: 0.9861 - auc_1: 0.9872 - val_loss: 0.1104 - val_accuracy: 0.9875 - val_recall_1: 0.9873 - val_precision_1: 0.9873 - val_auc_1: 0.9994
# Epoch 10/60
# 5/5 [==============================] - 2s 490ms/step - loss: 0.1127 - accuracy: 0.9625 - recall_1: 0.9241 - precision_1: 1.0000 - auc_1: 0.9958 - val_loss: 0.0539 - val_accuracy: 0.9937 - val_recall_1: 0.9873 - val_precision_1: 1.0000 - val_auc_1: 0.9999
# Epoch 11/60
# 5/5 [==============================] - 1s 268ms/step - loss: 0.0584 - accuracy: 0.9812 - recall_1: 0.9620 - precision_1: 1.0000 - auc_1: 0.9998 - val_loss: 0.0435 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 12/60
# 5/5 [==============================] - 1s 258ms/step - loss: 0.0276 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 0.0222 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 13/60
# 5/5 [==============================] - 1s 287ms/step - loss: 0.0174 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 0.0156 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 14/60
# 5/5 [==============================] - 1s 270ms/step - loss: 0.0150 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 15/60
# 5/5 [==============================] - 1s 276ms/step - loss: 0.0084 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 0.0050 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 16/60
# 5/5 [==============================] - 1s 261ms/step - loss: 0.0046 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 17/60
# 5/5 [==============================] - 1s 268ms/step - loss: 0.0030 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 0.0025 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 18/60
# 5/5 [==============================] - 1s 258ms/step - loss: 0.0025 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 19/60
# 5/5 [==============================] - 1s 250ms/step - loss: 0.0018 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 20/60
# 5/5 [==============================] - 1s 255ms/step - loss: 0.0012 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 21/60
# 5/5 [==============================] - 1s 264ms/step - loss: 0.0011 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 22/60
# 5/5 [==============================] - 1s 251ms/step - loss: 9.3840e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 8.4342e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 23/60
# 5/5 [==============================] - 1s 252ms/step - loss: 8.4456e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 7.8744e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 24/60
# 5/5 [==============================] - 1s 252ms/step - loss: 7.6018e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 6.8571e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 25/60
# 5/5 [==============================] - 1s 257ms/step - loss: 6.6424e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 6.3300e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 26/60
# 5/5 [==============================] - 1s 259ms/step - loss: 6.2236e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 5.8012e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 27/60
# 5/5 [==============================] - 1s 258ms/step - loss: 5.6342e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 5.2950e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 28/60
# 5/5 [==============================] - 1s 256ms/step - loss: 5.1466e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 4.9022e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 29/60
# 5/5 [==============================] - 1s 256ms/step - loss: 4.8017e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 4.5293e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 30/60
# 5/5 [==============================] - 1s 257ms/step - loss: 4.4556e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 4.2018e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 31/60
# 5/5 [==============================] - 1s 251ms/step - loss: 4.1063e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 3.9193e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 32/60
# 5/5 [==============================] - 1s 249ms/step - loss: 3.8296e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 3.6623e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 33/60
# 5/5 [==============================] - 1s 258ms/step - loss: 3.6168e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 3.4236e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 34/60
# 5/5 [==============================] - 1s 256ms/step - loss: 3.3615e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 3.2102e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 35/60
# 5/5 [==============================] - 1s 251ms/step - loss: 3.1795e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 3.0205e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 36/60
# 5/5 [==============================] - 1s 253ms/step - loss: 2.9749e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 2.8434e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 37/60
# 5/5 [==============================] - 1s 294ms/step - loss: 2.8120e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 2.6740e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 38/60
# 5/5 [==============================] - 2s 405ms/step - loss: 2.6356e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 2.5150e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 39/60
# 5/5 [==============================] - 1s 258ms/step - loss: 2.4764e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 2.3722e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 40/60
# 5/5 [==============================] - 1s 250ms/step - loss: 2.3426e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 2.2330e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 41/60
# 5/5 [==============================] - 1s 252ms/step - loss: 2.2126e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 2.0936e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 42/60
# 5/5 [==============================] - 1s 260ms/step - loss: 2.0589e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 1.9731e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 43/60
# 5/5 [==============================] - 1s 256ms/step - loss: 1.9288e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 1.8552e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 44/60
# 5/5 [==============================] - 1s 254ms/step - loss: 1.9157e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 1.7623e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 45/60
# 5/5 [==============================] - 1s 250ms/step - loss: 1.7361e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 1.6433e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 46/60
# 5/5 [==============================] - 1s 257ms/step - loss: 1.6472e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 1.5689e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 47/60
# 5/5 [==============================] - 1s 253ms/step - loss: 1.5324e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 1.4613e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 48/60
# 5/5 [==============================] - 1s 250ms/step - loss: 1.4400e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 1.3869e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 49/60
# 5/5 [==============================] - 1s 249ms/step - loss: 1.3776e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 1.3037e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 50/60
# 5/5 [==============================] - 1s 256ms/step - loss: 1.2726e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 1.2354e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 51/60
# 5/5 [==============================] - 1s 252ms/step - loss: 1.2269e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 1.1686e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 52/60
# 5/5 [==============================] - 1s 257ms/step - loss: 1.1766e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 1.1085e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 53/60
# 5/5 [==============================] - 1s 270ms/step - loss: 1.1001e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 1.0422e-04 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 54/60
# 5/5 [==============================] - 1s 258ms/step - loss: 1.0392e-04 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 9.9076e-05 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 55/60
# 5/5 [==============================] - 1s 261ms/step - loss: 9.8988e-05 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 9.3895e-05 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 56/60
# 5/5 [==============================] - 1s 262ms/step - loss: 9.3249e-05 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 8.8169e-05 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 57/60
# 5/5 [==============================] - 1s 258ms/step - loss: 8.7374e-05 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 8.2371e-05 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 58/60
# 5/5 [==============================] - 1s 256ms/step - loss: 8.1153e-05 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 7.7350e-05 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 59/60
# 5/5 [==============================] - 1s 256ms/step - loss: 7.7366e-05 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 7.2229e-05 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000
# Epoch 60/60
# 5/5 [==============================] - 1s 256ms/step - loss: 7.1664e-05 - accuracy: 1.0000 - recall_1: 1.0000 - precision_1: 1.0000 - auc_1: 1.0000 - val_loss: 6.7400e-05 - val_accuracy: 1.0000 - val_recall_1: 1.0000 - val_precision_1: 1.0000 - val_auc_1: 1.0000

# %%
len(vgg16_model.layers)
# Out:
# 19

# %%
import pickle


# Persist the model
model.save('./models_2/cucumber_model_main.h5')

# Save the history object to a file
with open('./models_2/cucumber_model_main_history.pkl', 'wb') as file:
    pickle.dump(history.history, file)

# %%
# Load model and history
# import pickle

# model.load_weights("./models_2/cucumber_model_main.h5")

# # Load the history object from the file
# with open('./models_2/cucumber_model_main_history.pkl', 'rb') as file:
#     history = pickle.load(file)

# %%
# Plot the training and validation loss graphs
plot_start_epoch = 2


train_loss = history.history['loss']
val_loss = history.history['val_loss']
val_acc = history.history['val_accuracy']
val_recall = history.history['val_recall_1']
val_precision = history.history['val_precision_1']
val_auc = history.history['val_auc_1']

print(train_loss)

# train_loss[:plot_start_epoch] = [0] * plot_start_epoch
# val_loss[:plot_start_epoch] = [0] * plot_start_epoch
# val_acc[:plot_start_epoch] = [0.7] * plot_start_epoch
# val_recall[:plot_start_epoch] = [0.7] * plot_start_epoch
# val_precision[:plot_start_epoch] = [0.7] * plot_start_epoch
# val_auc[:plot_start_epoch] = [0.7] * plot_start_epoch

plt.subplots(figsize=(12, 4))

# SUbplot 0
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training loss')
plt.plot(val_loss, label='Validation loss')
plt.ylim([-0.01, 1])
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# SUbplot 1
plt.subplot(1, 2, 2)
plt.plot(val_acc, label='Validation accuracy')
plt.plot(val_recall, label='Validation recall')
plt.plot(val_precision, label='Validation precision')
plt.plot(val_auc, label='Validation AUC')
plt.ylim([0.75, 1.01])
plt.title('Validation Accuracy, Recall, Precision and AUC')
plt.xlabel('Epochs')
plt.ylabel('Metric')
plt.legend()


plt.show()
# Out:
# [1.0204259157180786, 0.6485803723335266, 0.5284746885299683, 0.4627811312675476, 0.3831459879875183, 0.3006294071674347, 0.2509799599647522, 0.17588981986045837, 0.15727853775024414, 0.11265240609645844, 0.058381110429763794, 0.027624770998954773, 0.017412284389138222, 0.014959067106246948, 0.00841609574854374, 0.004643106833100319, 0.0030276491306722164, 0.002508104545995593, 0.0017555936938151717, 0.0012460045982152224, 0.0011383546516299248, 0.0009384005097672343, 0.0008445626008324325, 0.0007601820398122072, 0.0006642398657277226, 0.0006223566015250981, 0.0005634207045659423, 0.0005146565963514149, 0.00048016541404649615, 0.00044555668137036264, 0.0004106348496861756, 0.0003829637716989964, 0.00036168188671581447, 0.0003361462731845677, 0.00031795038376003504, 0.0002974936505779624, 0.00028119763010181487, 0.00026356446323916316, 0.0002476398949511349, 0.0002342635707464069, 0.0002212628023698926, 0.00020588775805663317, 0.00019288230396341532, 0.00019156704365741462, 0.00017360810306854546, 0.0001647228200454265, 0.00015324338164646178, 0.00014400439977180213, 0.0001377569860778749, 0.00012725655687972903, 0.00012268712453078479, 0.00011765989620471373, 0.0001100141234928742, 0.00010392089461674914, 9.898815915221348e-05, 9.324943675892428e-05, 8.73736062203534e-05, 8.115265518426895e-05, 7.736588304396719e-05, 7.166414434323087e-05]
# C:\Users\nikla\AppData\Local\Temp\ipykernel_13464\1760954864.py:24: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 2, 1)

# %%
# assume you have a trained keras model that performs binary classification
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
predictions = model.predict(x_valid)  # predict probabilities

# set a threshold for binary classification
threshold = 0.3

# convert probabilities to binary labels based on the threshold
predictions = (predictions > threshold).astype('int')

# assume binary_predictions is the binary label array
predicted_labels = np.where(predictions == 1, 'infected', 'healthy')

cm = confusion_matrix(y_valid, predictions)
# Print the confusion matrix
print(cm)

# Plot the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title(f'Threshold: {threshold}')
plt.show()
# Out:
# 2/2 [==============================] - 0s 92ms/step
# [[17  2]
#  [ 7 14]]
