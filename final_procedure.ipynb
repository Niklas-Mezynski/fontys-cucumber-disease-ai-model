# %% [markdown]
# # Procedure for image preprocessing
#
# ## Setup

# %%
# %load_ext nb_black
# %matplotlib notebook
import scipy
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import cv2
from PIL import ImageStat
import random
import os
from dotenv import load_dotenv

# %%
load_dotenv()
os.environ.get("TRAINING_DIRECTORY")
# Out:
# 'F:/big-data/uni/minor-a-systems/cucumber-dataset-compressed/normal-light'

# %% [markdown]
# ## Define constants and read the data

# %%
# Set the path to the folders containing the images
# train_dir = './training_data/'
train_dir = os.environ.get("TRAINING_DIRECTORY")

# Define the image size
img_height = 1024
img_width = 1024

# %%
# Read in the images and resize them
classes = ["healthy", "infected"]
images = []
labels = []
img_paths = []
img_dir = f"{train_dir}/mini-healthy"
for img_file in os.listdir(img_dir):
    path = os.path.join(img_dir, img_file)
    img = tf.keras.preprocessing.image.load_img(
        path, target_size=(img_height, img_width)
    )
    img = tf.keras.preprocessing.image.img_to_array(img, dtype=np.uint8)
    images.append(img)
    labels.append(0)
    img_paths.append(path)

img_dir = f"{train_dir}/mini-infected"
for img_file in os.listdir(img_dir):
    path = os.path.join(img_dir, img_file)
    img = tf.keras.preprocessing.image.load_img(
        path, target_size=(img_height, img_width)
    )
    img = tf.keras.preprocessing.image.img_to_array(img, dtype=np.uint8)
    images.append(img)
    labels.append(1)
    img_paths.append(path)

# Convert the data and labels to NumPy arrays
images = np.array(images)
labels = np.array(labels)
img_paths = np.array(img_paths)

# %%
images.shape
# Out:
# (300, 1024, 1024, 3)

# %% [markdown]
# ## Store some information about the dataset into a Dataframe
#
# - The cucumber image is masked (where the BLUE channel is below some threshold to filter out the background)
# - The first row is found where the mask contains at least 1/64 true values (sorting out possible single pixels that were not filtered out)
#     - This is considered the start y-pixel-coordinate of the cucumber
# - From there search the first row where there are less than 1/64 true values
#     - This is considered the end y-pixel-coordinate of the cucumber
# - Same process is repeated for columns to get the x-pixel-coordinates

# %%
# Map all images to their blue channel and flatten them
# images_blue_flattened = []
# for image in images:
#     images_blue_flattened.append(images[0][:, :, 2].ravel())
# images_blue_flattened = np.array(images_blue_flattened)
# print(f'Shape: {images_blue_flattened.shape}')

# -- Plot the average number of blue pixels per image --
# mean = np.median(images_blue_flattened, axis=0)
# plt.hist(mean, bins=int(255/5))

# -- Use the histogram to find the threshold for masking the background --

# %%
# Get the first y-pixel value where at least 1/64 of the pixels are masked
MASK_BLUE_THRESHOLD = 130


def get_first_and_last_cucumber_pixel(image):
    # masked_img = image[..., 2] < MASK_BLUE_THRESHOLD

    (_, masked_img) = cv2.threshold(
        image[..., 2], MASK_BLUE_THRESHOLD, 1, cv2.THRESH_BINARY_INV)

    first_cucumber_pixel_y = None
    last_cucumber_pixel_y = None
    threshold_height = img_height / 64
    for i in range(masked_img.shape[0]):
        if np.sum(masked_img[i, :]) > threshold_height:
            first_cucumber_pixel_y = i
            j = first_cucumber_pixel_y
            for j in range(i, masked_img.shape[0]):
                if np.sum(masked_img[j, :]) <= threshold_height:
                    last_cucumber_pixel_y = j
                    break
            break

    first_cucumber_pixel_x = None
    last_cucumber_pixel_x = None
    threshold_width = 2
    threshold_min_width = img_width / 16
    for i in range(masked_img.shape[1]):
        if np.sum(masked_img[:, i]) > threshold_width:
            first_cucumber_pixel_x = i
            for j in range(first_cucumber_pixel_x, masked_img.shape[0]):
                if np.sum(masked_img[:, j]) <= threshold_width and j - first_cucumber_pixel_x > threshold_min_width:
                    last_cucumber_pixel_x = j
                    break
            break

    return (
        (first_cucumber_pixel_x, first_cucumber_pixel_y),
        (last_cucumber_pixel_x, last_cucumber_pixel_y),
    )

# %%
# Create the DataFrame

df_records = []
for i in range(images.shape[0]):
    ((first_x, first_y), (last_x, last_y)) = get_first_and_last_cucumber_pixel(
        images[i]
    )
    df_records.append(
        {
            "idx": i,
            "label": classes[labels[i]],
            "first_cucumber_pixel_y": first_y,
            "last_cucumber_pixel_y": last_y,
            "first_cucumber_pixel_x": first_x,
            "last_cucumber_pixel_x": last_x,
            "cucumber_height": last_y - first_y,
            "cucumber_width": last_x - first_x,
        }
    )

df = pd.DataFrame(df_records)

print(df)
# Out:
#      idx     label  first_cucumber_pixel_y  last_cucumber_pixel_y  \
# 0      0   healthy                     333                    572
# 1      1   healthy                     331                    565
# 2      2   healthy                     327                    609
# 3      3   healthy                     352                    570
# 4      4   healthy                     324                    558
# ..   ...       ...                     ...                    ...
# 295  295  infected                     311                    643
# 296  296  infected                     311                    558
# 297  297  infected                     332                    581
# 298  298  infected                     311                    581
# 299  299  infected                     349                    636
#
#      first_cucumber_pixel_x  last_cucumber_pixel_x  cucumber_height  \
# 0                       163                    848              239
# 1                       151                    786              234
# 2                       110                    810              282
# 3                       142                    780              218
# 4                       166                    793              234
# ..                      ...                    ...              ...
# 295                     142                    811              332
# 296                      42                    798              247
# 297                      57                    734              249
# 298                      88                    787              270
# 299                      56                    860              287
#
#      cucumber_width
# 0               685
# 1               635
# 2               700
# 3               638
# 4               627
# ..              ...
# 295             669
# 296             756
# 297             677
# 298             699
# 299             804
#
# [300 rows x 8 columns]

# %% [markdown]
# ## Plot some random images from the dataset with their label and a box around the cucumber using the detected cucumber pixels calculated in the above Dataframe

# %%
def plot_cucumbers_with_boxes(images, df, classes, labels, img_paths):
    # Plot some random images with their label and a line for the first "cucumber pixel" detected
    plt.figure(figsize=(8, 8))
    # rand = random.randint(0, images.shape[0] - 10)
    for i in range(9):
        rand_idx = random.randint(0, images.shape[0] - 1)
        # rand_idx = rand + i
        # rand_idx = 25 + i
        ax = plt.subplot(3, 3, i + 1)
        rect = patches.Rectangle(
            (
                df.iloc[rand_idx]["first_cucumber_pixel_x"],
                df.iloc[rand_idx]["first_cucumber_pixel_y"],
            ),
            df.iloc[rand_idx]["cucumber_width"],
            df.iloc[rand_idx]["cucumber_height"],
            linewidth=1,
            edgecolor="r",
            facecolor="none",
        )

        ax.add_patch(rect)
        plt.imshow(images[rand_idx])
        path = img_paths[rand_idx].split(os.sep)[-1]
        plt.title(f"{classes[labels[rand_idx]]} ({path})")
        plt.axis("off")


plot_cucumbers_with_boxes(images, df, classes, labels, img_paths)

# %%
def remove_image_background(image):
    (_, masked_img) = cv2.threshold(
        image[..., 2], MASK_BLUE_THRESHOLD, 1, cv2.THRESH_BINARY_INV)
    # masked_img = image[..., 2] < MASK_BLUE_THRESHOLD

    img_mask_reshaped = np.zeros((*masked_img.shape, 3))
    img_mask_reshaped[np.where(masked_img)] = [1, 1, 1]

    return np.multiply(image, img_mask_reshaped).astype(np.uint8)

# %%
def plot_cucumber_without_bg(images, df):
    idx = random.randint(0, images.shape[0] - 1)
    image = images[idx]

    plt.figure(figsize=(6, 6))
    plt.subplot(1, 2, 1)
    plt.imshow(image)
    ax = plt.subplot(1, 2, 2)
    rect = patches.Rectangle(
        (df.iloc[idx]["first_cucumber_pixel_x"], df.iloc[idx]["first_cucumber_pixel_y"]),
        df.iloc[idx]["last_cucumber_pixel_x"] - df.iloc[idx]["first_cucumber_pixel_x"],
        df.iloc[idx]["last_cucumber_pixel_y"] - df.iloc[idx]["first_cucumber_pixel_y"],
        linewidth=1,
        edgecolor="r",
        facecolor="none",
    )

    ax.add_patch(rect)
    plt.imshow(remove_image_background(image))
    plt.show()


plot_cucumber_without_bg(images, df)

# %%
print(f'Images infected: {(len(df[df["label"]=="infected"]))}')
print(f'Images healthy: {(len(df[df["label"]=="healthy"]))}')
# Out:
# Images infected: 144
# Images healthy: 156

# %%
df_sorted_by_height = df.sort_values("cucumber_height", ascending=False)
img_paths[df_sorted_by_height["idx"][:10]]
# Out:
# array(['F:/big-data/uni/minor-a-systems/cucumber-dataset-compressed/normal-light/mini-infected\\0123.jpg',
#        'F:/big-data/uni/minor-a-systems/cucumber-dataset-compressed/normal-light/mini-infected\\0127.jpg',
#        'F:/big-data/uni/minor-a-systems/cucumber-dataset-compressed/normal-light/mini-infected\\0131.jpg',
#        'F:/big-data/uni/minor-a-systems/cucumber-dataset-compressed/normal-light/mini-infected\\0120.jpg',
#        'F:/big-data/uni/minor-a-systems/cucumber-dataset-compressed/normal-light/mini-healthy\\0132.jpg',
#        'F:/big-data/uni/minor-a-systems/cucumber-dataset-compressed/normal-light/mini-infected\\0136.jpg',
#        'F:/big-data/uni/minor-a-systems/cucumber-dataset-compressed/normal-light/mini-healthy\\0143.jpg',
#        'F:/big-data/uni/minor-a-systems/cucumber-dataset-compressed/normal-light/mini-healthy\\0133.jpg',
#        'F:/big-data/uni/minor-a-systems/cucumber-dataset-compressed/normal-light/mini-infected\\0135.jpg',
#        'F:/big-data/uni/minor-a-systems/cucumber-dataset-compressed/normal-light/mini-infected\\0134.jpg'],
#       dtype='<U95')

# %%
img_paths[df[df["first_cucumber_pixel_y"] < 4]["idx"]]
# Out:
# array([], dtype='<U95')

# %%
img_paths[df[df["last_cucumber_pixel_y"] > img_height - 4]["idx"]]
# Out:
# array([], dtype='<U95')

# %%
idx = random.randint(0, images.shape[0] - 1)
image = remove_image_background(images[idx])
df_entry = df.iloc[idx]

def crop_both_cucumber_tips(image, df_entry):
    total_height = df_entry["cucumber_height"]
    total_width = df_entry["cucumber_width"]

    if total_height > total_width:
        raise ValueError("Cucumber height is bigger than width")

    # Crop images to both tips
    img_left = image[
        df_entry["first_cucumber_pixel_y"] : df_entry["last_cucumber_pixel_y"],
        df_entry["first_cucumber_pixel_x"] : df_entry["first_cucumber_pixel_x"]
        + total_height,
    ]

    img_right = image[
        df_entry["first_cucumber_pixel_y"] : df_entry["last_cucumber_pixel_y"],
        df_entry["last_cucumber_pixel_x"]
        - total_height : df_entry["last_cucumber_pixel_x"],
    ]

    img_left = cv2.resize(src=img_left, dsize=(224, 224), interpolation=cv2.INTER_CUBIC)

    img_right = cv2.resize(src=img_right, dsize=(
        224, 224), interpolation=cv2.INTER_CUBIC)
    
    return (img_left, img_right)


img_left, img_right = crop_both_cucumber_tips(image, df_entry)

# %%
plt.figure(figsize=(6, 6))
plt.subplot(2, 2, 1)
plt.imshow(img_left, cmap=plt.get_cmap("gray"))
plt.subplot(2, 2, 2)
plt.imshow(img_right, cmap=plt.get_cmap("gray"))

plt.show()

# %%
# Testing if tip side can be determined by using average grayscale value

img_left_gray = np.dot(img_left[..., :], [0.2989, 0.5870, 0.1140])
img_right_gray = np.dot(img_right[..., :], [0.2989, 0.5870, 0.1140])

mean_brightness_left = np.mean(img_left_gray, axis=None)
mean_brightness_right = np.mean(img_right_gray, axis=None)

plt.figure(figsize=(6, 6))
plt.subplot(2, 2, 1)
plt.imshow(img_left_gray, cmap=plt.get_cmap("gray"))
if mean_brightness_left > mean_brightness_right:
    plt.title("TIP")

plt.subplot(2, 2, 2)
plt.imshow(img_right_gray, cmap=plt.get_cmap("gray"))
if mean_brightness_right > mean_brightness_left:
    plt.title("TIP")


plt.show()

# %%
idx = random.randint(0, images.shape[0] - 1)
image = remove_image_background(images[idx])
df_entry = df.iloc[idx]
cropped_size = 224

def crop_cucumber(image, df_entry, idx):
    total_height = df_entry["cucumber_height"]
    total_width = df_entry["cucumber_width"]

    cucumber_size = total_width

    if total_height > total_width:
        print(f'Cucumber height > width at image: {idx}')
        cucumber_size = total_height
        # raise ValueError("Cucumber height is bigger than width")

    # Crop images to both sides
    image = image[
        df_entry["first_cucumber_pixel_y"]: df_entry["first_cucumber_pixel_y"] + cucumber_size,
        df_entry["first_cucumber_pixel_x"]: df_entry["first_cucumber_pixel_x"] + cucumber_size,
    ]

    # print(f'Cropped img shape {image.shape}')

    image = cv2.resize(src=image, dsize=(cropped_size, cropped_size),
                       interpolation=cv2.INTER_CUBIC)
    return image


image = crop_cucumber(image, df_entry, idx)
plt.figure(figsize=(6, 6))
plt.imshow(image)

# %%
final_data = []
for (idx, image) in enumerate(images):
    image = remove_image_background(image)
    image = crop_cucumber(image, df.iloc[idx], idx)
    final_data.append(image)


final_data = np.array(final_data)
# final_data = final_data.astype('float32') / 255
final_data.shape
# Out:
# Cucumber height > width at image: 277
# Cucumber height > width at image: 278
# (300, 224, 224, 3)

# %%
i = random.randint(0, images.shape[0] - 1)

print(df.iloc[i])
plt.figure(figsize=(9, 9))
plt.subplot(2, 2, 1)
plt.imshow(final_data[i])
plt.subplot(2, 2, 2)
plt.imshow(images[i])
# Out:
# idx                            84
# label                     healthy
# first_cucumber_pixel_y        358
# last_cucumber_pixel_y         621
# first_cucumber_pixel_x        189
# last_cucumber_pixel_x         837
# cucumber_height               263
# cucumber_width                648
# Name: 84, dtype: object

# %%
plt.figure(figsize=(12,12))

for i in range(25):
    rand_idx = random.randint(0, (images.shape[0] / 2) - 10)
    # rand_idx = rand + i
    # rand_idx = 25 + i
    ax = plt.subplot(5, 5, i + 1)

    plt.imshow(final_data[rand_idx])
    path = img_paths[rand_idx].split(os.sep)[-1]
    plt.title(f"{classes[labels[rand_idx]]} ({path})")
    plt.axis("off")
plt.title("Healthy cucumbers")
plt.show()

plt.figure(figsize=(12, 12))

for i in range(25):
    rand_idx = random.randint((images.shape[0] / 2)+ 10, (images.shape[0] - 1))
    # rand_idx = rand + i
    # rand_idx = 25 + i
    ax = plt.subplot(5, 5, i + 1)

    plt.imshow(final_data[rand_idx])
    path = img_paths[rand_idx].split(os.sep)[-1]
    plt.title(f"{classes[labels[rand_idx]]} ({path})")
    plt.axis("off")
plt.title("Infected cucumbers")
plt.show()

# %% [markdown]
# ## AI Training
# In the following section the pre_processed images stored in `final_data` are used to train an AI model

# %%
from sklearn.model_selection import train_test_split

num_classes = 2
num_epochs = 8
batch_size = 32
input_shape = (final_data.shape[1], final_data.shape[2], final_data.shape[3])

# Split data into training and validation data
x_train, x_valid, y_train, y_valid = train_test_split(
    final_data, labels, test_size=0.2, shuffle=True)

print(f'Train: {x_train.shape} | {y_train.shape} Validation: {x_valid.shape} | {y_valid.shape}')
# Out:
# Train: (240, 224, 224, 3) | (240,) Validation: (60, 224, 224, 3) | (60,)

# %%
# Model using VGG16 and data segmentation
from sklearn.model_selection import train_test_split

# Split the dataset and normalize the pixel values to be in the range [0, 1]
x_train, x_valid, y_train, y_valid = train_test_split(
    final_data.astype('float32') / 255.0, labels, test_size=0.2, shuffle=True, random_state=187)

# Create an ImageDataGenerator for data augmentation
train_datagen = keras.preprocessing.image.ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

# Load the pre-trained VGG16 model (without the top layer)
vgg16_model = keras.applications.VGG16(weights='imagenet', include_top=False,
                    input_shape=input_shape)

# Freeze the weights of the pre-trained layers
for layer in vgg16_model.layers:
    layer.trainable = False

# Create a new model using the pre-trained VGG16 as a base
model = keras.models.Sequential()
model.add(vgg16_model)

# Add new layers for classification on top of the pre-trained base model
# model.add(keras.layers.GlobalAveragePooling2D())
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(256, activation='relu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy',
              metrics=['accuracy',
                       keras.metrics.Recall(),
                       keras.metrics.Precision(),
                       keras.metrics.AUC()])

# Checkpoints for the model
checkpoint = keras.callbacks.ModelCheckpoint(
    "./models/best_model.h5", monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# Train the model using data augmentation
history = model.fit(train_datagen.flow(x_train, y_train, batch_size=32),
                    steps_per_epoch=len(x_train) // 32, epochs=80, validation_data=train_datagen.flow(x_valid, y_valid, batch_size=32), callbacks=[checkpoint])
# Out:
# Epoch 1/80
# 7/7 [==============================] - ETA: 0s - loss: 2.7586 - accuracy: 0.5481 - recall_11: 0.6667 - precision_11: 0.5312 - auc_11: 0.5683
# Epoch 1: val_loss improved from inf to 1.06916, saving model to ./models\best_model.h5
# 7/7 [==============================] - 4s 455ms/step - loss: 2.7586 - accuracy: 0.5481 - recall_11: 0.6667 - precision_11: 0.5312 - auc_11: 0.5683 - val_loss: 1.0692 - val_accuracy: 0.6333 - val_recall_11: 0.7586 - val_precision_11: 0.5946 - val_auc_11: 0.6290
# Epoch 2/80
# 7/7 [==============================] - ETA: 0s - loss: 1.6345 - accuracy: 0.6154 - recall_11: 0.4646 - precision_11: 0.6301 - auc_11: 0.6405
# Epoch 2: val_loss improved from 1.06916 to 0.94440, saving model to ./models\best_model.h5
# 7/7 [==============================] - 2s 337ms/step - loss: 1.6345 - accuracy: 0.6154 - recall_11: 0.4646 - precision_11: 0.6301 - auc_11: 0.6405 - val_loss: 0.9444 - val_accuracy: 0.6000 - val_recall_11: 0.8276 - val_precision_11: 0.5581 - val_auc_11: 0.6618
# Epoch 3/80
# 7/7 [==============================] - ETA: 0s - loss: 1.1071 - accuracy: 0.6442 - recall_11: 0.6176 - precision_11: 0.6429 - auc_11: 0.6907
# Epoch 3: val_loss improved from 0.94440 to 0.69278, saving model to ./models\best_model.h5
# 7/7 [==============================] - 2s 307ms/step - loss: 1.1071 - accuracy: 0.6442 - recall_11: 0.6176 - precision_11: 0.6429 - auc_11: 0.6907 - val_loss: 0.6928 - val_accuracy: 0.7333 - val_recall_11: 0.5862 - val_precision_11: 0.8095 - val_auc_11: 0.7703
# Epoch 4/80
# 7/7 [==============================] - ETA: 0s - loss: 0.6037 - accuracy: 0.7548 - recall_11: 0.7745 - precision_11: 0.7383 - auc_11: 0.8225
# Epoch 4: val_loss improved from 0.69278 to 0.62355, saving model to ./models\best_model.h5
# 7/7 [==============================] - 2s 305ms/step - loss: 0.6037 - accuracy: 0.7548 - recall_11: 0.7745 - precision_11: 0.7383 - auc_11: 0.8225 - val_loss: 0.6235 - val_accuracy: 0.7000 - val_recall_11: 0.7931 - val_precision_11: 0.6571 - val_auc_11: 0.7786
# Epoch 5/80
# 7/7 [==============================] - ETA: 0s - loss: 0.7355 - accuracy: 0.6827 - recall_11: 0.6186 - precision_11: 0.6742 - auc_11: 0.7361
# Epoch 5: val_loss improved from 0.62355 to 0.51097, saving model to ./models\best_model.h5
# 7/7 [==============================] - 2s 318ms/step - loss: 0.7355 - accuracy: 0.6827 - recall_11: 0.6186 - precision_11: 0.6742 - auc_11: 0.7361 - val_loss: 0.5110 - val_accuracy: 0.7333 - val_recall_11: 0.6207 - val_precision_11: 0.7826 - val_auc_11: 0.8281
# Epoch 6/80
# 7/7 [==============================] - ETA: 0s - loss: 0.5762 - accuracy: 0.7455 - recall_11: 0.7685 - precision_11: 0.7217 - auc_11: 0.7878
# Epoch 6: val_loss improved from 0.51097 to 0.47243, saving model to ./models\best_model.h5
# 7/7 [==============================] - 2s 306ms/step - loss: 0.5762 - accuracy: 0.7455 - recall_11: 0.7685 - precision_11: 0.7217 - auc_11: 0.7878 - val_loss: 0.4724 - val_accuracy: 0.7667 - val_recall_11: 0.5172 - val_precision_11: 1.0000 - val_auc_11: 0.9260
# Epoch 7/80
# 7/7 [==============================] - ETA: 0s - loss: 0.4700 - accuracy: 0.7411 - recall_11: 0.7453 - precision_11: 0.7182 - auc_11: 0.8521
# Epoch 7: val_loss improved from 0.47243 to 0.46361, saving model to ./models\best_model.h5
# 7/7 [==============================] - 2s 313ms/step - loss: 0.4700 - accuracy: 0.7411 - recall_11: 0.7453 - precision_11: 0.7182 - auc_11: 0.8521 - val_loss: 0.4636 - val_accuracy: 0.7500 - val_recall_11: 0.7586 - val_precision_11: 0.7333 - val_auc_11: 0.8732
# Epoch 8/80
# 7/7 [==============================] - ETA: 0s - loss: 0.4484 - accuracy: 0.7885 - recall_11: 0.8500 - precision_11: 0.7456 - auc_11: 0.8807
# Epoch 8: val_loss did not improve from 0.46361
# 7/7 [==============================] - 2s 278ms/step - loss: 0.4484 - accuracy: 0.7885 - recall_11: 0.8500 - precision_11: 0.7456 - auc_11: 0.8807 - val_loss: 0.4722 - val_accuracy: 0.7833 - val_recall_11: 0.5862 - val_precision_11: 0.9444 - val_auc_11: 0.9038
# Epoch 9/80
# 7/7 [==============================] - ETA: 0s - loss: 0.4102 - accuracy: 0.8365 - recall_11: 0.7677 - precision_11: 0.8736 - auc_11: 0.8979
# Epoch 9: val_loss improved from 0.46361 to 0.43464, saving model to ./models\best_model.h5
# 7/7 [==============================] - 2s 308ms/step - loss: 0.4102 - accuracy: 0.8365 - recall_11: 0.7677 - precision_11: 0.8736 - auc_11: 0.8979 - val_loss: 0.4346 - val_accuracy: 0.8333 - val_recall_11: 0.7241 - val_precision_11: 0.9130 - val_auc_11: 0.8849
# Epoch 10/80
# 7/7 [==============================] - ETA: 0s - loss: 0.4055 - accuracy: 0.8214 - recall_11: 0.8073 - precision_11: 0.8224 - auc_11: 0.8943
# Epoch 10: val_loss did not improve from 0.43464
# 7/7 [==============================] - 2s 310ms/step - loss: 0.4055 - accuracy: 0.8214 - recall_11: 0.8073 - precision_11: 0.8224 - auc_11: 0.8943 - val_loss: 0.4568 - val_accuracy: 0.7667 - val_recall_11: 0.7931 - val_precision_11: 0.7419 - val_auc_11: 0.8732
# Epoch 11/80
# 7/7 [==============================] - ETA: 0s - loss: 0.4524 - accuracy: 0.7981 - recall_11: 0.8125 - precision_11: 0.7647 - auc_11: 0.8688
# Epoch 11: val_loss improved from 0.43464 to 0.41647, saving model to ./models\best_model.h5
# 7/7 [==============================] - 2s 306ms/step - loss: 0.4524 - accuracy: 0.7981 - recall_11: 0.8125 - precision_11: 0.7647 - auc_11: 0.8688 - val_loss: 0.4165 - val_accuracy: 0.8333 - val_recall_11: 0.7241 - val_precision_11: 0.9130 - val_auc_11: 0.8988
# Epoch 12/80
# 7/7 [==============================] - ETA: 0s - loss: 0.3707 - accuracy: 0.8221 - recall_11: 0.8039 - precision_11: 0.8283 - auc_11: 0.9210
# Epoch 12: val_loss improved from 0.41647 to 0.35513, saving model to ./models\best_model.h5
# 7/7 [==============================] - 2s 313ms/step - loss: 0.3707 - accuracy: 0.8221 - recall_11: 0.8039 - precision_11: 0.8283 - auc_11: 0.9210 - val_loss: 0.3551 - val_accuracy: 0.8833 - val_recall_11: 0.7931 - val_precision_11: 0.9583 - val_auc_11: 0.9399
# Epoch 13/80
# 7/7 [==============================] - ETA: 0s - loss: 0.4163 - accuracy: 0.7812 - recall_11: 0.7103 - precision_11: 0.8085 - auc_11: 0.8903
# Epoch 13: val_loss did not improve from 0.35513
# 7/7 [==============================] - 2s 293ms/step - loss: 0.4163 - accuracy: 0.7812 - recall_11: 0.7103 - precision_11: 0.8085 - auc_11: 0.8903 - val_loss: 0.4267 - val_accuracy: 0.8000 - val_recall_11: 0.8621 - val_precision_11: 0.7576 - val_auc_11: 0.9105
# Epoch 14/80
# 7/7 [==============================] - ETA: 0s - loss: 0.3583 - accuracy: 0.8462 - recall_11: 0.8469 - precision_11: 0.8300 - auc_11: 0.9232
# Epoch 14: val_loss did not improve from 0.35513
# 7/7 [==============================] - 2s 271ms/step - loss: 0.3583 - accuracy: 0.8462 - recall_11: 0.8469 - precision_11: 0.8300 - auc_11: 0.9232 - val_loss: 0.3797 - val_accuracy: 0.8667 - val_recall_11: 0.7586 - val_precision_11: 0.9565 - val_auc_11: 0.9177
# Epoch 15/80
# 7/7 [==============================] - ETA: 0s - loss: 0.3198 - accuracy: 0.8654 - recall_11: 0.8776 - precision_11: 0.8431 - auc_11: 0.9432
# Epoch 15: val_loss did not improve from 0.35513
# 7/7 [==============================] - 2s 301ms/step - loss: 0.3198 - accuracy: 0.8654 - recall_11: 0.8776 - precision_11: 0.8431 - auc_11: 0.9432 - val_loss: 0.3901 - val_accuracy: 0.8167 - val_recall_11: 0.6552 - val_precision_11: 0.9500 - val_auc_11: 0.9210
# Epoch 16/80
# 7/7 [==============================] - ETA: 0s - loss: 0.3315 - accuracy: 0.8702 - recall_11: 0.8000 - precision_11: 0.9048 - auc_11: 0.9336
# Epoch 16: val_loss did not improve from 0.35513
# 7/7 [==============================] - 2s 270ms/step - loss: 0.3315 - accuracy: 0.8702 - recall_11: 0.8000 - precision_11: 0.9048 - auc_11: 0.9336 - val_loss: 0.3687 - val_accuracy: 0.8333 - val_recall_11: 0.9655 - val_precision_11: 0.7568 - val_auc_11: 0.9566
# Epoch 17/80
# 7/7 [==============================] - ETA: 0s - loss: 0.3235 - accuracy: 0.8462 - recall_11: 0.8485 - precision_11: 0.8317 - auc_11: 0.9376
# Epoch 17: val_loss did not improve from 0.35513
# 7/7 [==============================] - 2s 288ms/step - loss: 0.3235 - accuracy: 0.8462 - recall_11: 0.8485 - precision_11: 0.8317 - auc_11: 0.9376 - val_loss: 0.4494 - val_accuracy: 0.7667 - val_recall_11: 0.5172 - val_precision_11: 1.0000 - val_auc_11: 0.9683
# Epoch 18/80
# 7/7 [==============================] - ETA: 0s - loss: 0.3688 - accuracy: 0.8606 - recall_11: 0.8700 - precision_11: 0.8447 - auc_11: 0.9203
# Epoch 18: val_loss improved from 0.35513 to 0.34555, saving model to ./models\best_model.h5
# 7/7 [==============================] - 2s 299ms/step - loss: 0.3688 - accuracy: 0.8606 - recall_11: 0.8700 - precision_11: 0.8447 - auc_11: 0.9203 - val_loss: 0.3456 - val_accuracy: 0.9000 - val_recall_11: 0.8621 - val_precision_11: 0.9259 - val_auc_11: 0.9349
# Epoch 19/80
# 7/7 [==============================] - ETA: 0s - loss: 0.3766 - accuracy: 0.8462 - recall_11: 0.7800 - precision_11: 0.8864 - auc_11: 0.9119
# Epoch 19: val_loss did not improve from 0.34555
# 7/7 [==============================] - 2s 299ms/step - loss: 0.3766 - accuracy: 0.8462 - recall_11: 0.7800 - precision_11: 0.8864 - auc_11: 0.9119 - val_loss: 0.3898 - val_accuracy: 0.8000 - val_recall_11: 0.9310 - val_precision_11: 0.7297 - val_auc_11: 0.9238
# Epoch 20/80
# 7/7 [==============================] - ETA: 0s - loss: 0.3293 - accuracy: 0.8606 - recall_11: 0.7917 - precision_11: 0.8941 - auc_11: 0.9354
# Epoch 20: val_loss did not improve from 0.34555
# 7/7 [==============================] - 2s 288ms/step - loss: 0.3293 - accuracy: 0.8606 - recall_11: 0.7917 - precision_11: 0.8941 - auc_11: 0.9354 - val_loss: 0.3496 - val_accuracy: 0.8500 - val_recall_11: 0.7241 - val_precision_11: 0.9545 - val_auc_11: 0.9527
# Epoch 21/80
# 7/7 [==============================] - ETA: 0s - loss: 0.3705 - accuracy: 0.8413 - recall_11: 0.8485 - precision_11: 0.8235 - auc_11: 0.9180
# Epoch 21: val_loss did not improve from 0.34555
# 7/7 [==============================] - 2s 265ms/step - loss: 0.3705 - accuracy: 0.8413 - recall_11: 0.8485 - precision_11: 0.8235 - auc_11: 0.9180 - val_loss: 0.3677 - val_accuracy: 0.8167 - val_recall_11: 0.6552 - val_precision_11: 0.9500 - val_auc_11: 0.9344
# Epoch 22/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2871 - accuracy: 0.8990 - recall_11: 0.8500 - precision_11: 0.9341 - auc_11: 0.9661
# Epoch 22: val_loss did not improve from 0.34555
# 7/7 [==============================] - 2s 268ms/step - loss: 0.2871 - accuracy: 0.8990 - recall_11: 0.8500 - precision_11: 0.9341 - auc_11: 0.9661 - val_loss: 0.3530 - val_accuracy: 0.8833 - val_recall_11: 0.9655 - val_precision_11: 0.8235 - val_auc_11: 0.9616
# Epoch 23/80
# 7/7 [==============================] - ETA: 0s - loss: 0.3099 - accuracy: 0.8654 - recall_11: 0.8700 - precision_11: 0.8529 - auc_11: 0.9425
# Epoch 23: val_loss did not improve from 0.34555
# 7/7 [==============================] - 2s 273ms/step - loss: 0.3099 - accuracy: 0.8654 - recall_11: 0.8700 - precision_11: 0.8529 - auc_11: 0.9425 - val_loss: 0.3534 - val_accuracy: 0.8500 - val_recall_11: 0.8276 - val_precision_11: 0.8571 - val_auc_11: 0.9255
# Epoch 24/80
# 7/7 [==============================] - ETA: 0s - loss: 0.3367 - accuracy: 0.8558 - recall_11: 0.8286 - precision_11: 0.8788 - auc_11: 0.9300
# Epoch 24: val_loss did not improve from 0.34555
# 7/7 [==============================] - 2s 286ms/step - loss: 0.3367 - accuracy: 0.8558 - recall_11: 0.8286 - precision_11: 0.8788 - auc_11: 0.9300 - val_loss: 0.3874 - val_accuracy: 0.8333 - val_recall_11: 0.8966 - val_precision_11: 0.7879 - val_auc_11: 0.9188
# Epoch 25/80
# 7/7 [==============================] - ETA: 0s - loss: 0.3221 - accuracy: 0.8750 - recall_11: 0.8585 - precision_11: 0.8750 - auc_11: 0.9399
# Epoch 25: val_loss improved from 0.34555 to 0.31736, saving model to ./models\best_model.h5
# 7/7 [==============================] - 2s 302ms/step - loss: 0.3221 - accuracy: 0.8750 - recall_11: 0.8585 - precision_11: 0.8750 - auc_11: 0.9399 - val_loss: 0.3174 - val_accuracy: 0.9000 - val_recall_11: 0.8966 - val_precision_11: 0.8966 - val_auc_11: 0.9455
# Epoch 26/80
# 7/7 [==============================] - ETA: 0s - loss: 0.3094 - accuracy: 0.8702 - recall_11: 0.8812 - precision_11: 0.8558 - auc_11: 0.9445
# Epoch 26: val_loss improved from 0.31736 to 0.28560, saving model to ./models\best_model.h5
# 7/7 [==============================] - 2s 283ms/step - loss: 0.3094 - accuracy: 0.8702 - recall_11: 0.8812 - precision_11: 0.8558 - auc_11: 0.9445 - val_loss: 0.2856 - val_accuracy: 0.8667 - val_recall_11: 0.7241 - val_precision_11: 1.0000 - val_auc_11: 0.9800
# Epoch 27/80
# 7/7 [==============================] - ETA: 0s - loss: 0.3283 - accuracy: 0.8365 - recall_11: 0.8269 - precision_11: 0.8431 - auc_11: 0.9326
# Epoch 27: val_loss did not improve from 0.28560
# 7/7 [==============================] - 2s 259ms/step - loss: 0.3283 - accuracy: 0.8365 - recall_11: 0.8269 - precision_11: 0.8431 - auc_11: 0.9326 - val_loss: 0.3841 - val_accuracy: 0.8167 - val_recall_11: 0.9310 - val_precision_11: 0.7500 - val_auc_11: 0.9444
# Epoch 28/80
# 7/7 [==============================] - ETA: 0s - loss: 0.3492 - accuracy: 0.8413 - recall_11: 0.7822 - precision_11: 0.8778 - auc_11: 0.9270
# Epoch 28: val_loss did not improve from 0.28560
# 7/7 [==============================] - 2s 263ms/step - loss: 0.3492 - accuracy: 0.8413 - recall_11: 0.7822 - precision_11: 0.8778 - auc_11: 0.9270 - val_loss: 0.3813 - val_accuracy: 0.8333 - val_recall_11: 0.8276 - val_precision_11: 0.8276 - val_auc_11: 0.9110
# Epoch 29/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2872 - accuracy: 0.8942 - recall_11: 0.9020 - precision_11: 0.8846 - auc_11: 0.9495
# Epoch 29: val_loss did not improve from 0.28560
# 7/7 [==============================] - 2s 260ms/step - loss: 0.2872 - accuracy: 0.8942 - recall_11: 0.9020 - precision_11: 0.8846 - auc_11: 0.9495 - val_loss: 0.3976 - val_accuracy: 0.8167 - val_recall_11: 0.6207 - val_precision_11: 1.0000 - val_auc_11: 0.9561
# Epoch 30/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2634 - accuracy: 0.8942 - recall_11: 0.8351 - precision_11: 0.9310 - auc_11: 0.9631
# Epoch 30: val_loss did not improve from 0.28560
# 7/7 [==============================] - 2s 251ms/step - loss: 0.2634 - accuracy: 0.8942 - recall_11: 0.8351 - precision_11: 0.9310 - auc_11: 0.9631 - val_loss: 0.2860 - val_accuracy: 0.9167 - val_recall_11: 0.9655 - val_precision_11: 0.8750 - val_auc_11: 0.9828
# Epoch 31/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2810 - accuracy: 0.8798 - recall_11: 0.8800 - precision_11: 0.8713 - auc_11: 0.9583
# Epoch 31: val_loss did not improve from 0.28560
# 7/7 [==============================] - 2s 262ms/step - loss: 0.2810 - accuracy: 0.8798 - recall_11: 0.8800 - precision_11: 0.8713 - auc_11: 0.9583 - val_loss: 0.4697 - val_accuracy: 0.7667 - val_recall_11: 0.5172 - val_precision_11: 1.0000 - val_auc_11: 0.9388
# Epoch 32/80
# 7/7 [==============================] - ETA: 0s - loss: 0.3547 - accuracy: 0.8606 - recall_11: 0.8586 - precision_11: 0.8500 - auc_11: 0.9214
# Epoch 32: val_loss did not improve from 0.28560
# 7/7 [==============================] - 2s 285ms/step - loss: 0.3547 - accuracy: 0.8606 - recall_11: 0.8586 - precision_11: 0.8500 - auc_11: 0.9214 - val_loss: 0.3129 - val_accuracy: 0.8833 - val_recall_11: 0.7586 - val_precision_11: 1.0000 - val_auc_11: 0.9483
# Epoch 33/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2990 - accuracy: 0.8702 - recall_11: 0.7822 - precision_11: 0.9405 - auc_11: 0.9542
# Epoch 33: val_loss did not improve from 0.28560
# 7/7 [==============================] - 2s 259ms/step - loss: 0.2990 - accuracy: 0.8702 - recall_11: 0.7822 - precision_11: 0.9405 - auc_11: 0.9542 - val_loss: 0.3241 - val_accuracy: 0.8833 - val_recall_11: 0.9655 - val_precision_11: 0.8235 - val_auc_11: 0.9583
# Epoch 34/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2623 - accuracy: 0.8846 - recall_11: 0.8600 - precision_11: 0.8958 - auc_11: 0.9560
# Epoch 34: val_loss improved from 0.28560 to 0.23830, saving model to ./models\best_model.h5
# 7/7 [==============================] - 2s 284ms/step - loss: 0.2623 - accuracy: 0.8846 - recall_11: 0.8600 - precision_11: 0.8958 - auc_11: 0.9560 - val_loss: 0.2383 - val_accuracy: 0.9000 - val_recall_11: 0.8276 - val_precision_11: 0.9600 - val_auc_11: 0.9789
# Epoch 35/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2579 - accuracy: 0.8942 - recall_11: 0.9307 - precision_11: 0.8624 - auc_11: 0.9617
# Epoch 35: val_loss improved from 0.23830 to 0.22038, saving model to ./models\best_model.h5
# 7/7 [==============================] - 2s 281ms/step - loss: 0.2579 - accuracy: 0.8942 - recall_11: 0.9307 - precision_11: 0.8624 - auc_11: 0.9617 - val_loss: 0.2204 - val_accuracy: 0.9167 - val_recall_11: 0.8276 - val_precision_11: 1.0000 - val_auc_11: 0.9844
# Epoch 36/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.8942 - recall_11: 0.8283 - precision_11: 0.9425 - auc_11: 0.9553
# Epoch 36: val_loss did not improve from 0.22038
# 7/7 [==============================] - 2s 256ms/step - loss: 0.2832 - accuracy: 0.8942 - recall_11: 0.8283 - precision_11: 0.9425 - auc_11: 0.9553 - val_loss: 0.2737 - val_accuracy: 0.9000 - val_recall_11: 0.8276 - val_precision_11: 0.9600 - val_auc_11: 0.9572
# Epoch 37/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2533 - accuracy: 0.8973 - recall_11: 0.8796 - precision_11: 0.9048 - auc_11: 0.9667
# Epoch 37: val_loss did not improve from 0.22038
# 7/7 [==============================] - 2s 271ms/step - loss: 0.2533 - accuracy: 0.8973 - recall_11: 0.8796 - precision_11: 0.9048 - auc_11: 0.9667 - val_loss: 0.3017 - val_accuracy: 0.8500 - val_recall_11: 0.7586 - val_precision_11: 0.9167 - val_auc_11: 0.9561
# Epoch 38/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2378 - accuracy: 0.9183 - recall_11: 0.8947 - precision_11: 0.9239 - auc_11: 0.9699
# Epoch 38: val_loss improved from 0.22038 to 0.21080, saving model to ./models\best_model.h5
# 7/7 [==============================] - 2s 275ms/step - loss: 0.2378 - accuracy: 0.9183 - recall_11: 0.8947 - precision_11: 0.9239 - auc_11: 0.9699 - val_loss: 0.2108 - val_accuracy: 0.9333 - val_recall_11: 0.8621 - val_precision_11: 1.0000 - val_auc_11: 0.9766
# Epoch 39/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2469 - accuracy: 0.9062 - recall_11: 0.9123 - precision_11: 0.9043 - auc_11: 0.9679
# Epoch 39: val_loss did not improve from 0.21080
# 7/7 [==============================] - 2s 273ms/step - loss: 0.2469 - accuracy: 0.9062 - recall_11: 0.9123 - precision_11: 0.9043 - auc_11: 0.9679 - val_loss: 0.4260 - val_accuracy: 0.8500 - val_recall_11: 0.6897 - val_precision_11: 1.0000 - val_auc_11: 0.9199
# Epoch 40/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2898 - accuracy: 0.8894 - recall_11: 0.8125 - precision_11: 0.9398 - auc_11: 0.9496
# Epoch 40: val_loss did not improve from 0.21080
# 7/7 [==============================] - 2s 262ms/step - loss: 0.2898 - accuracy: 0.8894 - recall_11: 0.8125 - precision_11: 0.9398 - auc_11: 0.9496 - val_loss: 0.3325 - val_accuracy: 0.8833 - val_recall_11: 1.0000 - val_precision_11: 0.8056 - val_auc_11: 0.9600
# Epoch 41/80
# 7/7 [==============================] - ETA: 0s - loss: 0.3144 - accuracy: 0.8654 - recall_11: 0.8878 - precision_11: 0.8365 - auc_11: 0.9429
# Epoch 41: val_loss did not improve from 0.21080
# 7/7 [==============================] - 2s 255ms/step - loss: 0.3144 - accuracy: 0.8654 - recall_11: 0.8878 - precision_11: 0.8365 - auc_11: 0.9429 - val_loss: 0.4229 - val_accuracy: 0.7833 - val_recall_11: 0.5517 - val_precision_11: 1.0000 - val_auc_11: 0.9377
# Epoch 42/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2432 - accuracy: 0.8942 - recall_11: 0.8866 - precision_11: 0.8866 - auc_11: 0.9707
# Epoch 42: val_loss did not improve from 0.21080
# 7/7 [==============================] - 2s 257ms/step - loss: 0.2432 - accuracy: 0.8942 - recall_11: 0.8866 - precision_11: 0.8866 - auc_11: 0.9707 - val_loss: 0.2822 - val_accuracy: 0.8500 - val_recall_11: 0.9310 - val_precision_11: 0.7941 - val_auc_11: 0.9677
# Epoch 43/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2171 - accuracy: 0.9183 - recall_11: 0.8713 - precision_11: 0.9565 - auc_11: 0.9707
# Epoch 43: val_loss did not improve from 0.21080
# 7/7 [==============================] - 2s 254ms/step - loss: 0.2171 - accuracy: 0.9183 - recall_11: 0.8713 - precision_11: 0.9565 - auc_11: 0.9707 - val_loss: 0.2751 - val_accuracy: 0.8667 - val_recall_11: 0.7931 - val_precision_11: 0.9200 - val_auc_11: 0.9577
# Epoch 44/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2246 - accuracy: 0.8990 - recall_11: 0.9388 - precision_11: 0.8598 - auc_11: 0.9761
# Epoch 44: val_loss did not improve from 0.21080
# 7/7 [==============================] - 2s 257ms/step - loss: 0.2246 - accuracy: 0.8990 - recall_11: 0.9388 - precision_11: 0.8598 - auc_11: 0.9761 - val_loss: 0.3630 - val_accuracy: 0.8833 - val_recall_11: 0.7931 - val_precision_11: 0.9583 - val_auc_11: 0.9461
# Epoch 45/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2713 - accuracy: 0.8750 - recall_11: 0.8598 - precision_11: 0.8762 - auc_11: 0.9550
# Epoch 45: val_loss did not improve from 0.21080
# 7/7 [==============================] - 2s 274ms/step - loss: 0.2713 - accuracy: 0.8750 - recall_11: 0.8598 - precision_11: 0.8762 - auc_11: 0.9550 - val_loss: 0.2838 - val_accuracy: 0.8667 - val_recall_11: 0.8276 - val_precision_11: 0.8889 - val_auc_11: 0.9455
# Epoch 46/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2436 - accuracy: 0.8798 - recall_11: 0.8365 - precision_11: 0.9158 - auc_11: 0.9677
# Epoch 46: val_loss did not improve from 0.21080
# 7/7 [==============================] - 2s 262ms/step - loss: 0.2436 - accuracy: 0.8798 - recall_11: 0.8365 - precision_11: 0.9158 - auc_11: 0.9677 - val_loss: 0.2825 - val_accuracy: 0.8333 - val_recall_11: 0.7586 - val_precision_11: 0.8800 - val_auc_11: 0.9544
# Epoch 47/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2266 - accuracy: 0.9087 - recall_11: 0.9429 - precision_11: 0.8839 - auc_11: 0.9793
# Epoch 47: val_loss did not improve from 0.21080
# 7/7 [==============================] - 2s 281ms/step - loss: 0.2266 - accuracy: 0.9087 - recall_11: 0.9429 - precision_11: 0.8839 - auc_11: 0.9793 - val_loss: 0.3173 - val_accuracy: 0.8667 - val_recall_11: 0.7241 - val_precision_11: 1.0000 - val_auc_11: 0.9844
# Epoch 48/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2585 - accuracy: 0.8990 - recall_11: 0.8431 - precision_11: 0.9451 - auc_11: 0.9650
# Epoch 48: val_loss did not improve from 0.21080
# 7/7 [==============================] - 2s 257ms/step - loss: 0.2585 - accuracy: 0.8990 - recall_11: 0.8431 - precision_11: 0.9451 - auc_11: 0.9650 - val_loss: 0.2667 - val_accuracy: 0.8833 - val_recall_11: 0.8621 - val_precision_11: 0.8929 - val_auc_11: 0.9572
# Epoch 49/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2052 - accuracy: 0.9152 - recall_11: 0.8991 - precision_11: 0.9245 - auc_11: 0.9775
# Epoch 49: val_loss improved from 0.21080 to 0.20704, saving model to ./models\best_model.h5
# 7/7 [==============================] - 2s 306ms/step - loss: 0.2052 - accuracy: 0.9152 - recall_11: 0.8991 - precision_11: 0.9245 - auc_11: 0.9775 - val_loss: 0.2070 - val_accuracy: 0.9000 - val_recall_11: 0.8276 - val_precision_11: 0.9600 - val_auc_11: 0.9900
# Epoch 50/80
# 7/7 [==============================] - ETA: 0s - loss: 0.1955 - accuracy: 0.9231 - recall_11: 0.9604 - precision_11: 0.8899 - auc_11: 0.9811
# Epoch 50: val_loss did not improve from 0.20704
# 7/7 [==============================] - 2s 257ms/step - loss: 0.1955 - accuracy: 0.9231 - recall_11: 0.9604 - precision_11: 0.8899 - auc_11: 0.9811 - val_loss: 0.3174 - val_accuracy: 0.8500 - val_recall_11: 0.6897 - val_precision_11: 1.0000 - val_auc_11: 0.9716
# Epoch 51/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2036 - accuracy: 0.9423 - recall_11: 0.8969 - precision_11: 0.9775 - auc_11: 0.9771
# Epoch 51: val_loss did not improve from 0.20704
# 7/7 [==============================] - 2s 265ms/step - loss: 0.2036 - accuracy: 0.9423 - recall_11: 0.8969 - precision_11: 0.9775 - auc_11: 0.9771 - val_loss: 0.2162 - val_accuracy: 0.9000 - val_recall_11: 0.8966 - val_precision_11: 0.8966 - val_auc_11: 0.9811
# Epoch 52/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2261 - accuracy: 0.9152 - recall_11: 0.9074 - precision_11: 0.9159 - auc_11: 0.9718
# Epoch 52: val_loss improved from 0.20704 to 0.19591, saving model to ./models\best_model.h5
# 7/7 [==============================] - 2s 303ms/step - loss: 0.2261 - accuracy: 0.9152 - recall_11: 0.9074 - precision_11: 0.9159 - auc_11: 0.9718 - val_loss: 0.1959 - val_accuracy: 0.9167 - val_recall_11: 0.8621 - val_precision_11: 0.9615 - val_auc_11: 0.9933
# Epoch 53/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2358 - accuracy: 0.8894 - recall_11: 0.8824 - precision_11: 0.8911 - auc_11: 0.9662
# Epoch 53: val_loss did not improve from 0.19591
# 7/7 [==============================] - 2s 269ms/step - loss: 0.2358 - accuracy: 0.8894 - recall_11: 0.8824 - precision_11: 0.8911 - auc_11: 0.9662 - val_loss: 0.2566 - val_accuracy: 0.9000 - val_recall_11: 0.9310 - val_precision_11: 0.8710 - val_auc_11: 0.9694
# Epoch 54/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2310 - accuracy: 0.9107 - recall_11: 0.8868 - precision_11: 0.9216 - auc_11: 0.9713
# Epoch 54: val_loss did not improve from 0.19591
# 7/7 [==============================] - 2s 323ms/step - loss: 0.2310 - accuracy: 0.9107 - recall_11: 0.8868 - precision_11: 0.9216 - auc_11: 0.9713 - val_loss: 0.2668 - val_accuracy: 0.8500 - val_recall_11: 0.7931 - val_precision_11: 0.8846 - val_auc_11: 0.9611
# Epoch 55/80
# 7/7 [==============================] - ETA: 0s - loss: 0.1742 - accuracy: 0.9135 - recall_11: 0.9200 - precision_11: 0.9020 - auc_11: 0.9859
# Epoch 55: val_loss did not improve from 0.19591
# 7/7 [==============================] - 2s 288ms/step - loss: 0.1742 - accuracy: 0.9135 - recall_11: 0.9200 - precision_11: 0.9020 - auc_11: 0.9859 - val_loss: 0.2691 - val_accuracy: 0.8833 - val_recall_11: 0.7931 - val_precision_11: 0.9583 - val_auc_11: 0.9744
# Epoch 56/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2465 - accuracy: 0.8702 - recall_11: 0.8298 - precision_11: 0.8764 - auc_11: 0.9614
# Epoch 56: val_loss did not improve from 0.19591
# 7/7 [==============================] - 2s 260ms/step - loss: 0.2465 - accuracy: 0.8702 - recall_11: 0.8298 - precision_11: 0.8764 - auc_11: 0.9614 - val_loss: 0.2952 - val_accuracy: 0.8833 - val_recall_11: 0.7586 - val_precision_11: 1.0000 - val_auc_11: 0.9466
# Epoch 57/80
# 7/7 [==============================] - ETA: 0s - loss: 0.1698 - accuracy: 0.9231 - recall_11: 0.8632 - precision_11: 0.9647 - auc_11: 0.9893
# Epoch 57: val_loss did not improve from 0.19591
# 7/7 [==============================] - 2s 277ms/step - loss: 0.1698 - accuracy: 0.9231 - recall_11: 0.8632 - precision_11: 0.9647 - auc_11: 0.9893 - val_loss: 0.2287 - val_accuracy: 0.9000 - val_recall_11: 0.8276 - val_precision_11: 0.9600 - val_auc_11: 0.9711
# Epoch 58/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2237 - accuracy: 0.8942 - recall_11: 0.9010 - precision_11: 0.8835 - auc_11: 0.9706
# Epoch 58: val_loss did not improve from 0.19591
# 7/7 [==============================] - 2s 274ms/step - loss: 0.2237 - accuracy: 0.8942 - recall_11: 0.9010 - precision_11: 0.8835 - auc_11: 0.9706 - val_loss: 0.4055 - val_accuracy: 0.8000 - val_recall_11: 0.5862 - val_precision_11: 1.0000 - val_auc_11: 0.9655
# Epoch 59/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2680 - accuracy: 0.8990 - recall_11: 0.9000 - precision_11: 0.8911 - auc_11: 0.9543
# Epoch 59: val_loss did not improve from 0.19591
# 7/7 [==============================] - 2s 298ms/step - loss: 0.2680 - accuracy: 0.8990 - recall_11: 0.9000 - precision_11: 0.8911 - auc_11: 0.9543 - val_loss: 0.2617 - val_accuracy: 0.9000 - val_recall_11: 0.7931 - val_precision_11: 1.0000 - val_auc_11: 0.9778
# Epoch 60/80
# 7/7 [==============================] - ETA: 0s - loss: 0.1751 - accuracy: 0.9327 - recall_11: 0.9020 - precision_11: 0.9583 - auc_11: 0.9856
# Epoch 60: val_loss did not improve from 0.19591
# 7/7 [==============================] - 2s 266ms/step - loss: 0.1751 - accuracy: 0.9327 - recall_11: 0.9020 - precision_11: 0.9583 - auc_11: 0.9856 - val_loss: 0.2615 - val_accuracy: 0.8500 - val_recall_11: 0.7586 - val_precision_11: 0.9167 - val_auc_11: 0.9572
# Epoch 61/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2241 - accuracy: 0.9183 - recall_11: 0.8878 - precision_11: 0.9355 - auc_11: 0.9669
# Epoch 61: val_loss improved from 0.19591 to 0.13995, saving model to ./models\best_model.h5
# 7/7 [==============================] - 2s 313ms/step - loss: 0.2241 - accuracy: 0.9183 - recall_11: 0.8878 - precision_11: 0.9355 - auc_11: 0.9669 - val_loss: 0.1399 - val_accuracy: 0.9833 - val_recall_11: 1.0000 - val_precision_11: 0.9667 - val_auc_11: 0.9944
# Epoch 62/80
# 7/7 [==============================] - ETA: 0s - loss: 0.1445 - accuracy: 0.9567 - recall_11: 0.9495 - precision_11: 0.9592 - auc_11: 0.9935
# Epoch 62: val_loss did not improve from 0.13995
# 7/7 [==============================] - 2s 266ms/step - loss: 0.1445 - accuracy: 0.9567 - recall_11: 0.9495 - precision_11: 0.9592 - auc_11: 0.9935 - val_loss: 0.2225 - val_accuracy: 0.8833 - val_recall_11: 0.7931 - val_precision_11: 0.9583 - val_auc_11: 0.9811
# Epoch 63/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2390 - accuracy: 0.8973 - recall_11: 0.9000 - precision_11: 0.8919 - auc_11: 0.9648
# Epoch 63: val_loss did not improve from 0.13995
# 7/7 [==============================] - 2s 287ms/step - loss: 0.2390 - accuracy: 0.8973 - recall_11: 0.9000 - precision_11: 0.8919 - auc_11: 0.9648 - val_loss: 0.1464 - val_accuracy: 0.9500 - val_recall_11: 0.8966 - val_precision_11: 1.0000 - val_auc_11: 1.0000
# Epoch 64/80
# 7/7 [==============================] - ETA: 0s - loss: 0.1607 - accuracy: 0.9423 - recall_11: 0.9216 - precision_11: 0.9592 - auc_11: 0.9874
# Epoch 64: val_loss did not improve from 0.13995
# 7/7 [==============================] - 2s 260ms/step - loss: 0.1607 - accuracy: 0.9423 - recall_11: 0.9216 - precision_11: 0.9592 - auc_11: 0.9874 - val_loss: 0.1865 - val_accuracy: 0.9333 - val_recall_11: 0.9310 - val_precision_11: 0.9310 - val_auc_11: 0.9855
# Epoch 65/80
# 7/7 [==============================] - ETA: 0s - loss: 0.1792 - accuracy: 0.9423 - recall_11: 0.9192 - precision_11: 0.9579 - auc_11: 0.9809
# Epoch 65: val_loss did not improve from 0.13995
# 7/7 [==============================] - 2s 257ms/step - loss: 0.1792 - accuracy: 0.9423 - recall_11: 0.9192 - precision_11: 0.9579 - auc_11: 0.9809 - val_loss: 0.1893 - val_accuracy: 0.9167 - val_recall_11: 0.8966 - val_precision_11: 0.9286 - val_auc_11: 0.9833
# Epoch 66/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2272 - accuracy: 0.8929 - recall_11: 0.8879 - precision_11: 0.8879 - auc_11: 0.9673
# Epoch 66: val_loss did not improve from 0.13995
# 7/7 [==============================] - 2s 281ms/step - loss: 0.2272 - accuracy: 0.8929 - recall_11: 0.8879 - precision_11: 0.8879 - auc_11: 0.9673 - val_loss: 0.1940 - val_accuracy: 0.9167 - val_recall_11: 0.8276 - val_precision_11: 1.0000 - val_auc_11: 0.9889
# Epoch 67/80
# 7/7 [==============================] - ETA: 0s - loss: 0.1810 - accuracy: 0.9471 - recall_11: 0.9327 - precision_11: 0.9604 - auc_11: 0.9838
# Epoch 67: val_loss did not improve from 0.13995
# 7/7 [==============================] - 2s 269ms/step - loss: 0.1810 - accuracy: 0.9471 - recall_11: 0.9327 - precision_11: 0.9604 - auc_11: 0.9838 - val_loss: 0.2391 - val_accuracy: 0.9000 - val_recall_11: 0.8276 - val_precision_11: 0.9600 - val_auc_11: 0.9733
# Epoch 68/80
# 7/7 [==============================] - ETA: 0s - loss: 0.1928 - accuracy: 0.9375 - recall_11: 0.9000 - precision_11: 0.9677 - auc_11: 0.9778
# Epoch 68: val_loss did not improve from 0.13995
# 7/7 [==============================] - 2s 289ms/step - loss: 0.1928 - accuracy: 0.9375 - recall_11: 0.9000 - precision_11: 0.9677 - auc_11: 0.9778 - val_loss: 0.2119 - val_accuracy: 0.9500 - val_recall_11: 0.8966 - val_precision_11: 1.0000 - val_auc_11: 0.9633
# Epoch 69/80
# 7/7 [==============================] - ETA: 0s - loss: 0.1977 - accuracy: 0.9038 - recall_11: 0.9100 - precision_11: 0.8922 - auc_11: 0.9767
# Epoch 69: val_loss did not improve from 0.13995
# 7/7 [==============================] - 2s 265ms/step - loss: 0.1977 - accuracy: 0.9038 - recall_11: 0.9100 - precision_11: 0.8922 - auc_11: 0.9767 - val_loss: 0.2970 - val_accuracy: 0.8667 - val_recall_11: 0.7241 - val_precision_11: 1.0000 - val_auc_11: 0.9744
# Epoch 70/80
# 7/7 [==============================] - ETA: 0s - loss: 0.1294 - accuracy: 0.9423 - recall_11: 0.8889 - precision_11: 0.9888 - auc_11: 0.9944
# Epoch 70: val_loss did not improve from 0.13995
# 7/7 [==============================] - 2s 268ms/step - loss: 0.1294 - accuracy: 0.9423 - recall_11: 0.8889 - precision_11: 0.9888 - auc_11: 0.9944 - val_loss: 0.2359 - val_accuracy: 0.9167 - val_recall_11: 0.9310 - val_precision_11: 0.9000 - val_auc_11: 0.9694
# Epoch 71/80
# 7/7 [==============================] - ETA: 0s - loss: 0.1823 - accuracy: 0.9327 - recall_11: 0.9314 - precision_11: 0.9314 - auc_11: 0.9791
# Epoch 71: val_loss did not improve from 0.13995
# 7/7 [==============================] - 2s 260ms/step - loss: 0.1823 - accuracy: 0.9327 - recall_11: 0.9314 - precision_11: 0.9314 - auc_11: 0.9791 - val_loss: 0.2776 - val_accuracy: 0.9167 - val_recall_11: 0.8276 - val_precision_11: 1.0000 - val_auc_11: 0.9561
# Epoch 72/80
# 7/7 [==============================] - ETA: 0s - loss: 0.1593 - accuracy: 0.9375 - recall_11: 0.9158 - precision_11: 0.9457 - auc_11: 0.9858
# Epoch 72: val_loss did not improve from 0.13995
# 7/7 [==============================] - 2s 263ms/step - loss: 0.1593 - accuracy: 0.9375 - recall_11: 0.9158 - precision_11: 0.9457 - auc_11: 0.9858 - val_loss: 0.3319 - val_accuracy: 0.8667 - val_recall_11: 0.7241 - val_precision_11: 1.0000 - val_auc_11: 0.9383
# Epoch 73/80
# 7/7 [==============================] - ETA: 0s - loss: 0.1916 - accuracy: 0.9241 - recall_11: 0.8868 - precision_11: 0.9495 - auc_11: 0.9763
# Epoch 73: val_loss did not improve from 0.13995
# 7/7 [==============================] - 2s 284ms/step - loss: 0.1916 - accuracy: 0.9241 - recall_11: 0.8868 - precision_11: 0.9495 - auc_11: 0.9763 - val_loss: 0.2559 - val_accuracy: 0.9000 - val_recall_11: 0.9310 - val_precision_11: 0.8710 - val_auc_11: 0.9672
# Epoch 74/80
# 7/7 [==============================] - ETA: 0s - loss: 0.1857 - accuracy: 0.9327 - recall_11: 0.9208 - precision_11: 0.9394 - auc_11: 0.9804
# Epoch 74: val_loss did not improve from 0.13995
# 7/7 [==============================] - 2s 260ms/step - loss: 0.1857 - accuracy: 0.9327 - recall_11: 0.9208 - precision_11: 0.9394 - auc_11: 0.9804 - val_loss: 0.2525 - val_accuracy: 0.8667 - val_recall_11: 0.7241 - val_precision_11: 1.0000 - val_auc_11: 0.9883
# Epoch 75/80
# 7/7 [==============================] - ETA: 0s - loss: 0.1794 - accuracy: 0.9183 - recall_11: 0.9381 - precision_11: 0.8922 - auc_11: 0.9803
# Epoch 75: val_loss did not improve from 0.13995
# 7/7 [==============================] - 2s 266ms/step - loss: 0.1794 - accuracy: 0.9183 - recall_11: 0.9381 - precision_11: 0.8922 - auc_11: 0.9803 - val_loss: 0.3104 - val_accuracy: 0.9000 - val_recall_11: 0.7931 - val_precision_11: 1.0000 - val_auc_11: 0.9672
# Epoch 76/80
# 7/7 [==============================] - ETA: 0s - loss: 0.1629 - accuracy: 0.9279 - recall_11: 0.9300 - precision_11: 0.9208 - auc_11: 0.9834
# Epoch 76: val_loss did not improve from 0.13995
# 7/7 [==============================] - 2s 265ms/step - loss: 0.1629 - accuracy: 0.9279 - recall_11: 0.9300 - precision_11: 0.9208 - auc_11: 0.9834 - val_loss: 0.2284 - val_accuracy: 0.9167 - val_recall_11: 0.8276 - val_precision_11: 1.0000 - val_auc_11: 0.9727
# Epoch 77/80
# 7/7 [==============================] - ETA: 0s - loss: 0.1728 - accuracy: 0.9286 - recall_11: 0.8774 - precision_11: 0.9688 - auc_11: 0.9850
# Epoch 77: val_loss did not improve from 0.13995
# 7/7 [==============================] - 2s 275ms/step - loss: 0.1728 - accuracy: 0.9286 - recall_11: 0.8774 - precision_11: 0.9688 - auc_11: 0.9850 - val_loss: 0.2562 - val_accuracy: 0.9000 - val_recall_11: 0.9655 - val_precision_11: 0.8485 - val_auc_11: 0.9722
# Epoch 78/80
# 7/7 [==============================] - ETA: 0s - loss: 0.1863 - accuracy: 0.9327 - recall_11: 0.9500 - precision_11: 0.9135 - auc_11: 0.9808
# Epoch 78: val_loss did not improve from 0.13995
# 7/7 [==============================] - 2s 291ms/step - loss: 0.1863 - accuracy: 0.9327 - recall_11: 0.9500 - precision_11: 0.9135 - auc_11: 0.9808 - val_loss: 0.5003 - val_accuracy: 0.8167 - val_recall_11: 0.6207 - val_precision_11: 1.0000 - val_auc_11: 0.9616
# Epoch 79/80
# 7/7 [==============================] - ETA: 0s - loss: 0.2235 - accuracy: 0.9183 - recall_11: 0.8842 - precision_11: 0.9333 - auc_11: 0.9701
# Epoch 79: val_loss did not improve from 0.13995
# 7/7 [==============================] - 2s 264ms/step - loss: 0.2235 - accuracy: 0.9183 - recall_11: 0.8842 - precision_11: 0.9333 - auc_11: 0.9701 - val_loss: 0.2175 - val_accuracy: 0.9333 - val_recall_11: 0.8966 - val_precision_11: 0.9630 - val_auc_11: 0.9672
# Epoch 80/80
# 7/7 [==============================] - ETA: 0s - loss: 0.1699 - accuracy: 0.9279 - recall_11: 0.9175 - precision_11: 0.9271 - auc_11: 0.9826
# Epoch 80: val_loss did not improve from 0.13995
# 7/7 [==============================] - 2s 269ms/step - loss: 0.1699 - accuracy: 0.9279 - recall_11: 0.9175 - precision_11: 0.9271 - auc_11: 0.9826 - val_loss: 0.2180 - val_accuracy: 0.9500 - val_recall_11: 0.9310 - val_precision_11: 0.9643 - val_auc_11: 0.9755

# %%
# Persist the model
model.save('./models/cucumber_model_main.h5')

# %%
# Plot the training and validation loss graphs
plt.plot(history.history['loss'][2:], label='Training loss')
plt.plot(history.history['val_loss'][2:], label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.load_weights("./models/best_model.h5")

# %%
# assume you have a trained keras model that performs binary classification
from sklearn.metrics import confusion_matrix
predictions = model.predict(x_valid)  # predict probabilities

# set a threshold for binary classification
threshold = 0.5

# convert probabilities to binary labels based on the threshold
predictions = (predictions > threshold).astype('int')

# assume binary_predictions is the binary label array
predicted_labels = np.where(predictions == 1, 'infected', 'healthy')


# Print the confusion matrix
cm = confusion_matrix(y_valid, predictions)
print("Confusion matrix:")
print(cm)
# print(y_valid)
# print(predictions)
# Out:
# 2/2 [==============================] - 0s 100ms/step
# Confusion matrix:
# [[31  0]
#  [ 6 23]]
